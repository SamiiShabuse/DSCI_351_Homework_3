# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

print("✓ All libraries imported successfully!")
print(f"Pandas version: {pd.__version__}")
print(f"NumPy version: {np.__version__}")
print(f"Matplotlib version: {plt.matplotlib.__version__}")
print(f"Seaborn version: {sns.__version__}")

# %% [markdown]
# ## Section 4: Import Libraries and Test
#
# Test that all major libraries are working correctly.

# %%
import subprocess
import sys

# List installed packages
result = subprocess.run([sys.executable, '-m', 'pip', 'list'], capture_output=True, text=True)
print("Installed packages:")
print(result.stdout)

# %% [markdown]
# ## Section 3: Verify Environment Setup
#
# Check that packages are installed correctly.

# %%
import subprocess
import sys

# Install essential packages
packages = ['jupyter', 'pandas', 'numpy', 'matplotlib', 'seaborn']
for package in packages:
    subprocess.check_call([sys.executable, '-m', 'pip', 'install', package])

# %% [markdown]
# ## Section 2: Install Required Packages
#
# Install essential packages into the virtual environment.

# %% [markdown]
# ## Section 1: Virtual Environment Setup
#
# The virtual environment has been created at `.venv/` using Python 3.13.3.
#
# **Commands executed:**
# - `python -m venv .venv`
# - Activate with: `.\.venv\Scripts\activate` (Windows)

# %% [markdown]
# # DSCI 351 Homework 3 - Main Notebook
#
# This notebook contains the main analysis and solutions for the homework assignment.
